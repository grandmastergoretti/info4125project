# %% [markdown]
# # INFO 4125 Project
#
# *Fall 2025*
# **Date:** today
# - Fiona Huang
# - JinPeng Li
# - Nick-Aurel Mugirashaka
# - Goretti Muriithi
# - Wassan Nasreddin
# - Jocelyn Wong
# - Chenglin Zheng
#
#
# **Project topic:**

# %%
#code

# %%
#code
